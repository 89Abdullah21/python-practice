# %% [markdown]
# # Day 1: Modules
#
# Module is the external code written by other people <br>
# Module is the code that we import into our code. We resue other people's code<br>
# It saves time and effort<br>
# We can import the module using the import/from statement<br>
